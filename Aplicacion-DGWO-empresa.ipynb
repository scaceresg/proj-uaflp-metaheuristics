# %%
import os
import sys
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from alg_lobo_gris import AlgLoboGris

# Set of parameters to evaluate
set_params = [[15, 1, 0.4, 0.2, 1], [15, 3, 0.2, 0.4, 0.6]]

t_limite = 600
n_rondas = 10

lobo_gris = AlgLoboGris(archivo_datos=f'./furniture_application.txt')

# %%
lobo_gris.calcular_fitness(np.array([[2, 1, 8, 7, 6, 3, 4, 5], [0, 0, 0, 0, 1, 0, 0, 1]]))
# Out:
# 45262.77

# %%
lobo_gris.dibujar_layout(np.array([[2, 1, 8, 7, 6, 3, 4, 5], [0, 0, 0, 0, 1, 0, 0, 1]]))

# %%
lobo_gris.calcular_fitness(np.array([[8, 6, 7, 1, 2, 5, 4, 3], [0, 0, 0, 0, 1, 0, 0, 1]]))
# Out:
# 45267.12

# %%
lobo_gris.dibujar_layout(np.array([[8, 6, 7, 1, 2, 5, 4, 3], [0, 0, 0, 0, 1, 0, 0, 1]]))
